# %%
import numpy as np
import pandas as pd
from time import sleep
from bs4 import BeautifulSoup
import requests
from IPython.core.display import display, HTML

# %%
pd.read_excel('player_goals.xlsx', index_col=0)
# urls = ['https://www.infogol.net/en/leagues/english-premier-league-top-goalscorers-2019-20/138', 
#  'https://www.infogol.net/en/leagues/italian-serie-a-top-goalscorers-2019-20/163',
#  'https://www.infogol.net/en/leagues/spanish-la-liga-top-goalscorers-2019-20/159',
#  'https://www.infogol.net/en/leagues/german-bundesliga-top-goalscorers-2019-20/155',
#  'https://www.infogol.net/en/leagues/french-ligue-1-top-goalscorers-2019-20/139',
#  'https://www.infogol.net/en/leagues/portuguese-primeira-liga-top-goalscorers-2019-20/247',
#  'https://www.infogol.net/en/leagues/dutch-eredivisie-top-goalscorers-2019-20/246',
#  'https://www.infogol.net/en/leagues/brazilian-serie-a-top-goalscorers-2019/117']

# for url in urls:
    
#     r = requests.get(url)
#     page = r.text
#     soup = BeautifulSoup(r.content, 'lxml')
        
#     print(url)
    
#     player = [name.text for name in (soup.find(class_='table').find_all('span', class_='player-display-name'))]


# response = requests.get(url)

# page = response.text

# soup = BeautifulSoup(page, "lxml")

# page
# Out:
#                           Played (+sub)  Mins  Goals     xG  xG Per Avg Match  \
# Player
# Jamie Vardy                      34 (1)  3271     23  19.39              0.56
# Danny Ings                       32 (6)  3009     22  16.64              0.52
# Pierre-Emerick Aubameyang        35 (1)  3392     22  16.16              0.45
# Raheem Sterling                  30 (3)  2836     20  20.35              0.68
# Mohamed Salah                    33 (1)  3045     19  20.48              0.63
# ...                                 ...   ...    ...    ...               ...
# Bruno Melo                       13 (1)  1284      3   2.99              0.22
# Cícero                           32 (0)  3004      3   3.78              0.11
# Clayson                         22 (10)  2180      3   2.74              0.11
# Everton Ribeiro                  27 (5)  2671      3   3.31              0.11
# Felipe Melo                      24 (0)  2180      3   2.92              0.12
#
#                            Shots  On Target  Shots Per Avg Match  \
# Player
# Jamie Vardy                   89         42                 2.58
# Danny Ings                    93         37                 2.93
# Pierre-Emerick Aubameyang     93         42                 2.60
# Raheem Sterling               99         38                 3.31
# Mohamed Salah                132         59                 4.11
# ...                          ...        ...                  ...
# Bruno Melo                    12          5                 0.88
# Cícero                        30         12                 0.94
# Clayson                       34         15                 1.48
# Everton Ribeiro               54         13                 1.92
# Felipe Melo                   28          6                 1.22
#
#                            On Target Per Avg Match
# Player
# Jamie Vardy                                   1.21
# Danny Ings                                    1.16
# Pierre-Emerick Aubameyang                     1.17
# Raheem Sterling                               1.27
# Mohamed Salah                                 1.84
# ...                                            ...
# Bruno Melo                                    0.36
# Cícero                                        0.37
# Clayson                                       0.65
# Everton Ribeiro                               0.46
# Felipe Melo                                   0.26
#
# [640 rows x 9 columns]

# %%
soup.find('')
# Out:
# <title>Infogol</title>

# %%
for attributes in soup.find_all(class_='table'):
    print(attributes.prettify())
